# %% [markdown]
# <a href="https://colab.research.google.com/github/tsangrebecca/BloomTech/blob/main/Sprint_1/Module4/O2_UseAppropriateTerminologyWhenReferringToPartsOfAMatplotlibGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# generate X and Y values
X = np.linspace(0.5, 3.5, 100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

# create the figure object with a size of 8x8 inches
fig = plt.figure(figsize=(8,8))

# create the figure axes with a single plot
ax = fig.add_subplot(1,1,1)

# finally, plot!
# choosing different colors

# plot a solid magenta line, width=2
ax.plot(X, Y1, c='m', lw=2, label='magenta signal')

# plot an orange dash-dot line, width=3
ax.plot(X, Y2, c='orange', lw=3, linestyle='-.', label='orange signal')

# plot yellow circle markers with a green edge, line width=0 (not visible)
ax.plot(X, Y3, linewidth=0, marker='o', markerfacecolor='y', markeredgecolor='g')

# set title and x- y-axis labels
ax.set_title("Anatomy of a figure (modified)", fontsize=16)
ax.set_xlabel("X axis label")
ax.set_ylabel("Y axis label")

# plot the legend using the labels defined earlier
ax.legend()

# display the plot
plt.show()
