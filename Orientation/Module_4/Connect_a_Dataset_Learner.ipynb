# %% [markdown]
# <a href="https://colab.research.google.com/github/tsangrebecca/BloomTech/blob/main/Orientation/Connect_a_Dataset_Learner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #How to Connect a Dataset on Google Colab

# %% [markdown]
# ---
# ##Introduction:
#
# While at BloomTech, you will be working with datasets from many different sources. Some you will even create or scrape for yourself.
#
# In this lesson, we will go over **two** different ways to read in the [cars dataset, stored in Kaggle.](https://www.kaggle.com/datasets/mandragorassster/autocsv)
#
# - Connecting to a dataset stored online (through a url)
# - Connecting to a local dataset, stored on your personal computer.
# ---
# We will be using the **Pandas** library to connect our dataset to a DataFrame object.
#
# **In the event of outdated links, uncomment (remove the #) from the following line of code and skip to the next section.**

# %%
import pandas as pd
#autos= sns.load_dataset('mpg')

# %% [markdown]
# ### From a Url
# Note that the url is different from the repository. You will need to click on "Raw" to see the dataset in its basic format.

# %%
#read in and display a dataframe

#this link is connected to Kaggle, as opposed to Github in the video, so can't use this method.
# pd.read_csv("URL")

# %%
#assign the data to a dataframe object
# df = pd.read_csv("URL")

# %% [markdown]
# ### From a Local Directory
# Colab has a few ways to upload a file, and a built-in library for Colab use. You will need to download the raw csv file directly from Github.
#
# *Note: This will not work in Jupyter Notebooks*

# %%
#opens a link to upload files
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-97000896-6dc9-4103-9d92-28feccdcba58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-97000896-6dc9-4103-9d92-28feccdcba58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#use Pandas to read in the dataset CASE SENSITIVE
pd.read_csv("auto.csv")
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 387          4         140.0        86.0  2790.0          15.6          82
# 388          4          97.0        52.0  2130.0          24.6          82
# 389          4         135.0        84.0  2295.0          11.6          82
# 390          4         120.0        79.0  2625.0          18.6          82
# 391          4         119.0        82.0  2720.0          19.4          82
#
#      origin   mpg
# 0         1  18.0
# 1         1  15.0
# ...

# %% [markdown]
# Note that you can also drag documents on the Colab directory. The file will only be available while the environment kernel is running.

# %%
# save the file to a dataframe object
df = pd.read_csv("auto.csv")
df.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0          8         307.0       130.0  3504.0          12.0          70
# 1          8         350.0       165.0  3693.0          11.5          70
# 2          8         318.0       150.0  3436.0          11.0          70
# 3          8         304.0       150.0  3433.0          12.0          70
# 4          8         302.0       140.0  3449.0          10.5          70
#
#    origin   mpg
# 0       1  18.0
# 1       1  15.0
# 2       1  18.0
# 3       1  16.0
# 4       1  17.0

# %% [markdown]
# #### Resources for Connecting to Other Data Sets:
# - Google Drive: https://colab.research.google.com/notebooks/io.ipynb
# - Github: https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb
# - Kaggle: https://www.kaggle.com/general/74235
#
# #### Resources for Data Sets
# - [data.world](https://data.world/)
# - [kaggle](https://www.kaggle.com/)
