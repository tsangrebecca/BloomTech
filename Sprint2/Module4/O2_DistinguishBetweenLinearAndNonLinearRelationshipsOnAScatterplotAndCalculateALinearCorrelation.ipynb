# %% [markdown]
# <a href="https://colab.research.google.com/github/tsangrebecca/BloomTech/blob/main/Sprint2/Module4/O2_DistinguishBetweenLinearAndNonLinearRelationshipsOnAScatterplotAndCalculateALinearCorrelation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/bloominstituteoftechnology/data-science-practice-datasets/main/unit_1/Concrete/Concrete_Data.csv'

# Use specific columns only when importing data:
mycols = ['cement', 'water','coarse_agg', 'strength']
concrete = pd.read_csv(url, usecols=mycols)

# %%
# use seaborn's pairplot function to discover relationships between variables
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(concrete)

plt.savefig('/Users/nicole/data_science_LS/data-science-canvas-images/unit_1/sprint_3/new/mod1_obj2_concrete_pair.png',
            transparent=False, dpi=100)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-99344c398f6c> in <cell line: 6>()
#       4 sns.pairplot(concrete)
#       5
# ----> 6 plt.savefig('/Users/nicole/data_science_LS/data-science-canvas-images/unit_1/sprint_3/new/mod1_obj2_concrete_pair.png',
#       7             transparent=False, dpi=100)
#       8
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3341                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3342
# ...

# %%
from scipy.stats import pearsonr

# Calculate the correlation coefficient
# (return only the coefficient)
strength_cement, _ = pearsonr(concrete['strength'], concrete['cement'])
strength_water, _ = pearsonr(concrete['strength'], concrete['water'])

print('The correlation between strength-cement:', round(strength_cement, 3))
print('The correlation between strength-water:', round(strength_water, 2))
# Out:
# The correlation between strength-cement: 0.498
# The correlation between strength-water: -0.29

# %%
# pearson's score is the covariance of 2 variables divided by the product of stdev of each data sample
# it is the normalization of the covariance between the 2 variables!!!

# %%
# usually we draw the line of 0.5 to say if there's a notable correlation

# %%
# for non-Gaussian distribution, we can use Spearman correlation coeff
