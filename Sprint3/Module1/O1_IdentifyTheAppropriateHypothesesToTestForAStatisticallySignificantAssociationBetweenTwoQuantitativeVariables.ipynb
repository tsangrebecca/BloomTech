# %% [markdown]
# <a href="https://colab.research.google.com/github/tsangrebecca/BloomTech/blob/main/Sprint3/Module1/O1_IdentifyTheAppropriateHypothesesToTestForAStatisticallySignificantAssociationBetweenTwoQuantitativeVariables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

crashes = sns.load_dataset("car_crashes")

# limit the data to only the columns we need
crashes = crashes[["total", "speeding", "alcohol"]]

crashes.head()
# Out:
#    total  speeding  alcohol
# 0   18.8     7.332    5.640
# 1   18.1     7.421    4.525
# 2   18.6     6.510    5.208
# 3   22.4     4.032    5.824
# 4   12.0     4.200    3.360

# %%
import matplotlib.pyplot as plt

# make scatter plot
sns.lmplot(data=crashes, x="alcohol", y="total", ci=None)
plt.show() # to remove the line of text following the diagram
