# %% [markdown]
# <a href="https://colab.research.google.com/github/tsangrebecca/BloomTech/blob/main/Sprint3/Module1/O4_IdentifyViolationsOfTheAssumptionsForLinearRegressionAndArticulateWhyCorrelationDoesNotImplyCausationInferenceForLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Don't use Linear Regression for
#
#
# *   Categorical data
# *   Non-Linear relationships
# *   Outliers without adjusting for them

# %% [markdown]
# Categorical Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

dots = sns.load_dataset("dots")
sns.lmplot(data=dots, x='time', y='coherence', ci=95)
plt.show()

# %%
# doesn't even make sense. ALWAYS PLOT MY DATA BEFORE I FIT A MODEL!

# %% [markdown]
# Non-Linear Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

temps = pd.read_csv("denver_temps.csv")
sns.lmplot(data=temps, x='time', y='temperature', ci=95)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e130548acb1c> in <cell line: 5>()
#       3 import pandas as pd
#       4
# ----> 5 temps = pd.read_csv("denver_temps.csv")
#       6 sns.lmplot(data=temps, x='time', y='temperature', ci=95)
#       7 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...
